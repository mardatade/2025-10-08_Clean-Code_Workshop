# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Get cmems package and log in
#
# (only necessary once)

# %% [raw]
# %pip install copernicusmarine

# %% [raw]
# import copernicusmarine

# %% [raw]
# copernicusmarine.login()

# %% [markdown]
# ## Imports

# %%
import copernicusmarine

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Global Ocean Biogeochemistry Hindcast

# %%
ds_gobh = copernicusmarine.open_dataset(
    dataset_id="cmems_mod_glo_bgc_my_0.25deg_P1M-m"
)
ds_gobh
# Out:
# INFO - 2025-10-06T12:25:30Z - Selected dataset version: "202406"
# INFO - 2025-10-06T12:25:30Z - Selected dataset part: "default"
# <xarray.Dataset> Size: 955GB
# Dimensions:    (depth: 75, latitude: 681, longitude: 1440, time: 360)
# Coordinates:
#   * depth      (depth) float32 300B 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * latitude   (latitude) float32 3kB -80.0 -79.75 -79.5 ... 89.5 89.75 90.0
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * time       (time) datetime64[ns] 3kB 1993-01-01 1993-02-01 ... 2022-12-01
# Data variables:
#     chl        (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     fe         (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     no3        (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     nppv       (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     o2         (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     ph         (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     phyc       (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     po4        (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     si         (time, depth, latitude, longitude) float32 106GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     spco2      (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
# Attributes:
#     institution:  Mercator Ocean
#     producer:     CMEMS - Global Monitoring and Forecasting Centre
#     credit:       E.U. Copernicus Marine Service Information (CMEMS)
#     title:        Monthly mean fields for product GLOBAL_REANALYSIS_BIO_001_029
#     source:       MERCATOR FREEBIORYS2V4
#     Conventions:  CF-1.6
#     contact:      servicedesk.cmems@mercator-ocean.eu
#     references:   http://marine.copernicus.eu

# %%
ds_gobh_coarse = ds_gobh.isel(depth=slice(None, None, 15)).sel(time=slice("1995", "1996"))
ds_gobh_coarse
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:    (depth: 5, latitude: 681, longitude: 1440, time: 24)
# Coordinates:
#   * depth      (depth) float32 20B 0.5058 35.74 199.8 947.4 3.139e+03
#   * latitude   (latitude) float32 3kB -80.0 -79.75 -79.5 ... 89.5 89.75 90.0
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * time       (time) datetime64[ns] 192B 1995-01-01 1995-02-01 ... 1996-12-01
# Data variables:
#     chl        (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     fe         (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     no3        (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     nppv       (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     o2         (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     ph         (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     phyc       (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     po4        (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     si         (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     spco2      (time, latitude, longitude) float32 94MB dask.array<chunksize=(24, 681, 1440), meta=np.ndarray>
# Attributes:
#     institution:  Mercator Ocean
#     producer:     CMEMS - Global Monitoring and Forecasting Centre
#     credit:       E.U. Copernicus Marine Service Information (CMEMS)
#     title:        Monthly mean fields for product GLOBAL_REANALYSIS_BIO_001_029
#     source:       MERCATOR FREEBIORYS2V4
#     Conventions:  CF-1.6
#     contact:      servicedesk.cmems@mercator-ocean.eu
#     references:   http://marine.copernicus.eu

# %%
# %%time

ds_gobh_coarse = ds_gobh_coarse.compute()
# Out:
# CPU times: user 2min, sys: 2min 58s, total: 4min 59s
# Wall time: 16min 15s

# %%
ds_gobh_coarse.drop_encoding().to_netcdf("data/cmems_mod_glo_bgc_my_0.25deg_P1M-m_depth-skip-15_time-1995-1996.nc")

# %% [markdown]
# ### Global Ocean Ensemble Physics Reanalysis

# %%
ds_goepr = copernicusmarine.open_dataset(dataset_id="cmems_mod_glo_phy-mnstd_my_0.25deg_P1M-m")
ds_goepr
# Out:
# INFO - 2025-10-06T12:42:10Z - Selected dataset version: "202311"
# INFO - 2025-10-06T12:42:10Z - Selected dataset part: "default"
# <xarray.Dataset> Size: 887GB
# Dimensions:       (depth: 75, latitude: 681, longitude: 1440, time: 372)
# Coordinates:
#   * depth         (depth) float32 300B 0.5058 1.556 ... 5.698e+03 5.902e+03
#   * latitude      (latitude) float32 3kB -80.0 -79.75 -79.5 ... 89.5 89.75 90.0
#   * longitude     (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * time          (time) datetime64[ns] 3kB 1993-01-01 1993-02-01 ... 2023-12-01
# Data variables: (12/16)
#     mlotst_mean   (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     mlotst_std    (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     siconc_mean   (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     siconc_std    (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     sithick_mean  (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     sithick_std   (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     ...            ...
#     uo_mean       (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     uo_std        (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     vo_mean       (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     vo_std        (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     zos_mean      (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     zos_std       (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
# Attributes:
#     institution:  Mercator Ocean
#     producer:     CMEMS - Global Monitoring and Forecasting Centre
#     history:      Creation 2023-October-31 12:55:11 GMT+0200
#     credit:       E.U. Copernicus Marine Service Information (CMEMS)
#     title:        Monthly mean fields for product GLOBAL_MULTIYEAR_PHY_ENS_00...
#     source:       Copernicus Marine Service
#     Conventions:  CF-1.6
#     contact:      servicedesk.cmems@mercator-ocean.eu
#     references:   http://marine.copernicus.eu

# %%
ds_goepr = ds_goepr.drop([v for v in ds_goepr.data_vars if "_std" in v])
ds_goepr = ds_goepr.rename_vars({v: v[:-5] for v in ds_goepr.data_vars if "_mean" in v})
ds_goepr
# Out:
# /tmp/ipykernel_3618/2256134270.py:1: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   ds_goepr = ds_goepr.drop([v for v in ds_goepr.data_vars if "_std" in v])
# <xarray.Dataset> Size: 444GB
# Dimensions:    (depth: 75, latitude: 681, longitude: 1440, time: 372)
# Coordinates:
#   * depth      (depth) float32 300B 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * latitude   (latitude) float32 3kB -80.0 -79.75 -79.5 ... 89.5 89.75 90.0
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * time       (time) datetime64[ns] 3kB 1993-01-01 1993-02-01 ... 2023-12-01
# Data variables:
#     mlotst     (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     siconc     (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     sithick    (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
#     so         (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     thetao     (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     uo         (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     vo         (time, depth, latitude, longitude) float32 109GB dask.array<chunksize=(50, 2, 681, 1440), meta=np.ndarray>
#     zos        (time, latitude, longitude) float32 1GB dask.array<chunksize=(50, 681, 1440), meta=np.ndarray>
# Attributes:
#     institution:  Mercator Ocean
#     producer:     CMEMS - Global Monitoring and Forecasting Centre
#     history:      Creation 2023-October-31 12:55:11 GMT+0200
#     credit:       E.U. Copernicus Marine Service Information (CMEMS)
#     title:        Monthly mean fields for product GLOBAL_MULTIYEAR_PHY_ENS_00...
#     source:       Copernicus Marine Service
#     Conventions:  CF-1.6
#     contact:      servicedesk.cmems@mercator-ocean.eu
#     references:   http://marine.copernicus.eu

# %%
ds_goepr_coarse = ds_goepr.isel(depth=slice(None, None, 15)).sel(time=slice("1995", "1996"))
ds_goepr_coarse
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (depth: 5, latitude: 681, longitude: 1440, time: 24)
# Coordinates:
#   * depth      (depth) float32 20B 0.5058 35.74 199.8 947.4 3.139e+03
#   * latitude   (latitude) float32 3kB -80.0 -79.75 -79.5 ... 89.5 89.75 90.0
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * time       (time) datetime64[ns] 192B 1995-01-01 1995-02-01 ... 1996-12-01
# Data variables:
#     mlotst     (time, latitude, longitude) float32 94MB dask.array<chunksize=(24, 681, 1440), meta=np.ndarray>
#     siconc     (time, latitude, longitude) float32 94MB dask.array<chunksize=(24, 681, 1440), meta=np.ndarray>
#     sithick    (time, latitude, longitude) float32 94MB dask.array<chunksize=(24, 681, 1440), meta=np.ndarray>
#     so         (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     thetao     (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     uo         (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     vo         (time, depth, latitude, longitude) float32 471MB dask.array<chunksize=(24, 1, 681, 1440), meta=np.ndarray>
#     zos        (time, latitude, longitude) float32 94MB dask.array<chunksize=(24, 681, 1440), meta=np.ndarray>
# Attributes:
#     institution:  Mercator Ocean
#     producer:     CMEMS - Global Monitoring and Forecasting Centre
#     history:      Creation 2023-October-31 12:55:11 GMT+0200
#     credit:       E.U. Copernicus Marine Service Information (CMEMS)
#     title:        Monthly mean fields for product GLOBAL_MULTIYEAR_PHY_ENS_00...
#     source:       Copernicus Marine Service
#     Conventions:  CF-1.6
#     contact:      servicedesk.cmems@mercator-ocean.eu
#     references:   http://marine.copernicus.eu

# %%
# %%time

ds_goepr_coarse = ds_goepr_coarse.compute()
# Out:
# CPU times: user 58.9 s, sys: 1min 28s, total: 2min 27s
# Wall time: 7min 51s

# %%
ds_goepr_coarse.drop_encoding().to_netcdf("data/cmems_mod_glo_phy-mnstd_my_0.25deg_P1M-m_depth-skip-15_time-1995-1996.nc")
